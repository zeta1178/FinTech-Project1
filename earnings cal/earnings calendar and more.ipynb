# %%
try:
    # For Python 3.0 and later
    from urllib.request import urlopen
# from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen
    
import pandas as pd
import certifi
import json

# %%
def get_jsonparsed_data(url):
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

# %%
#url

# %%
url = ("https://financialmodelingprep.com/api/v3/earning_calendar/AAPL?apikey=eef11245e039afd02560c03e5e86851d")
data=get_jsonparsed_data(url)
# Out:
# /tmp/ipykernel_5407/654040892.py:2: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 url = ("https://financialmodelingprep.com/api/v3/earning_calendar/AAPL?apikey=eef11245e039afd02560c03e5e86851d")
# ----> 2 data=get_jsonparsed_data(url)
#
# Input In [10], in get_jsonparsed_data(url)
#       1 def get_jsonparsed_data(url):
# ----> 2     response = urlopen(url, cafile=certifi.where())
#       3     data = response.read().decode("utf-8")
#       4     return json.loads(data)
#
# File /usr/lib/python3.10/urllib/request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File /usr/lib/python3.10/urllib/request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File /usr/lib/python3.10/urllib/request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File /usr/lib/python3.10/urllib/request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File /usr/lib/python3.10/urllib/request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File /usr/lib/python3.10/urllib/request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404:

# %%
print(json.dumps(data, indent=4))
# Out:
# []

# %%
pd.DataFrame(data).T
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame(data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def get_jsonparsed_data(url):
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

url = ("https://financialmodelingprep.com/api/v3/key-metrics/AAPL?period=quarter&limit=1&apikey=eef11245e039afd02560c03e5e86851d")
data=get_jsonparsed_data(url)
# Out:
# C:\Users\mct46\AppData\Local\Temp\ipykernel_13416\3750622633.py:2: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())

# %%
print(json.dumps(data, indent=4))
pd.DataFrame(data)
# Out:
# [
#     {
#         "symbol": "AAPL",
#         "date": "2022-03-26",
#         "period": "Q2",
#         "revenuePerShare": 5.9345801576454065,
#         "netIncomePerShare": 1.5257699556190674,
#         "operatingCashFlowPerShare": 1.718306140342529,
#         "freeCashFlowPerShare": 1.5649360616369579,
#         "cashPerShare": 3.14250044717688,
#         "bookValuePerShare": 4.11177006152617,
#         "tangibleBookValuePerShare": 4.11177006152617,
#         "shareholdersEquityPerShare": 4.11177006152617,
#         "interestDebtPerShare": 7.3617637778674165,
#         "marketCap": 2863962036950.069,
#         "enterpriseValue": 2955845036950.069,
#         "peRatio": 28.628169101859946,
#         "priceToSalesRatio": 29.441004512326213,
#         "pocfratio": 101.68153223567666,
#         "pfcfRatio": 111.64673463862735,
#         "pbRatio": 42.49264880710499,
#         "ptbRatio": 42.49264880710499,
#         "evToSales": 30.385544901725662,
#         "enterpriseValueOverEBITDA": 88.05806407930613,
#         "evToOperatingCashFlow": 104.94372779060105,
#         "evToFreeCashFlow": 115.22863858373884,
#         "earningsYield": 0.008732657653044174,
#         "freeCashFlowYield": 0.008956822635581334,
#         "debtToEquity": 1.5330049407261235,
#         "debtToAssets": 0.807794970655503,
#         "netDebtToEBITDA": 2.7373015163702448,
#         "currentRatio": 0.9268438058788468,
#         "interestCoverage": 43.3849493487699,
#         "incomeQuality": 1.126189524190324,
#         "dividendYield": 0.0012552540688802,
#         "payoutRatio": 0.14374250299880048,
#         "salesGeneralAndAdministrativeToRevenue": 0.0,
#         "researchAndDdevelopementToRevenue": 0.06565718867575403,
#         "intangiblesToTotalAssets": 0.0,
#         "capexToOperatingCashFlow": -0.08925655045089824,
#         "capexToRevenue": -0.025843458952692282,
#         "capexToDepreciation": -0.9185239313116551,
#         "stockBasedCompensationToRevenue": 0.023150147001377495,
#         "grahamNumber": 11.880923471958665,
#         "roic": 0.13434220314222464,
#         "returnOnTangibleAssets": 0.07132224193097626,
#         "grahamNetNet": -11.894538975888077,
#         "workingCapital": -9328000000,
#         "tangibleAssetValue": null,
#         "netCurrentAssetValue": -165083000000,
#         "investedCapital": 1.780159943025861,
#         "averageReceivables": 55326500000,
#         "averagePayables": 63522000000,
#         "averageInventory": 5668000000,
#         "daysSalesOutstanding": 42.003330660581014,
#         "daysPayablesOutstanding": 86.64960982474096,
#         "daysOfInventoryOnHand": 8.98042727389024,
#         "receivablesTurnover": 2.1426872246696034,
#         "payablesTurnover": 1.0386659580122244,
#         "inventoryTurnover": 10.021794871794873,
#         "roe": 0.37107375480348376,
#         "capexPerShare": -0.15337007870557118
#     }
# ]
#   symbol        date period  revenuePerShare  netIncomePerShare  \
# 0   AAPL  2022-03-26     Q2          5.93458            1.52577
#
#    operatingCashFlowPerShare  freeCashFlowPerShare  cashPerShare  \
# 0                   1.718306              1.564936        3.1425
#
#    bookValuePerShare  tangibleBookValuePerShare  ...  averagePayables  \
# 0            4.11177                    4.11177  ...      63522000000
#
#    averageInventory  daysSalesOutstanding  daysPayablesOutstanding  \
# 0        5668000000             42.003331                 86.64961
#
#    daysOfInventoryOnHand  receivablesTurnover  payablesTurnover  \
# 0               8.980427             2.142687          1.038666
#
#    inventoryTurnover       roe  capexPerShare
# 0          10.021795  0.371074       -0.15337
#
# [1 rows x 60 columns]

# %%
url = ("https://financialmodelingprep.com/api/v3/financial-growth/AAPL?period=quarter&limit=1&apikey=eef11245e039afd02560c03e5e86851d")

# %%
data=get_jsonparsed_data(url)
print(json.dumps(data, indent=4))
pd.DataFrame(data)
# Out:
# C:\Users\mct46\AppData\Local\Temp\ipykernel_13416\3750622633.py:2: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())
# [
#     {
#         "symbol": "AAPL",
#         "date": "2022-03-26",
#         "period": "Q2",
#         "revenueGrowth": -0.2151518818830933,
#         "grossProfitGrowth": -0.2154010655752816,
#         "ebitgrowth": -0.2774055148476668,
#         "operatingIncomeGrowth": -0.2774055148476668,
#         "netIncomeGrowth": -0.2777938203869477,
#         "epsgrowth": -0.2748815165876777,
#         "epsdilutedGrowth": -0.28095238095238095,
#         "weightedAverageSharesGrowth": 0.0,
#         "weightedAverageSharesDilutedGrowth": 0.0,
#         "dividendsperShareGrowth": -0.036709539121114645,
#         "operatingCashFlowGrowth": -0.40028957117915087,
#         "freeCashFlowGrowth": -0.41915177863822656,
#         "tenYRevenueGrowthPerShare": 2.9588547429331293,
#         "fiveYRevenueGrowthPerShare": 1.3451962777224704,
#         "threeYRevenueGrowthPerShare": 0.9125156605723226,
#         "tenYOperatingCFGrowthPerShare": 2.2136389158740255,
#         "fiveYOperatingCFGrowthPerShare": 1.868165380003745,
#         "threeYOperatingCFGrowthPerShare": 1.879958726919568,
#         "tenYNetIncomeGrowthPerShare": 2.431774072258586,
#         "fiveYNetIncomeGrowthPerShare": 1.8917780042232375,
#         "threeYNetIncomeGrowthPerShare": 1.4674533698574066,
#         "tenYShareholdersEquityGrowthPerShare": 0.04863398790446925,
#         "fiveYShareholdersEquityGrowthPerShare": -0.35898178781363926,
#         "threeYShareholdersEquityGrowthPerShare": -0.27380671818448193,
#         "tenYDividendperShareGrowthPerShare": 0.0,
#         "fiveYDividendperShareGrowthPerShare": 0.5261118387909579,
#         "threeYDividendperShareGrowthPerShare": 0.19094727639089842,
#         "receivablesGrowth": -0.3042465480514306,
#         "inventoryGrowth": -0.07079646017699115,
#         "assetGrowth": -0.08008845959112361,
#         "bookValueperShareGrowth": -0.06301785019184854,
#         "debtGrowth": -0.02294011303115686,
#         "rdexpenseGrowth": 0.012844909609895337,
#         "sgaexpensesGrowth": 0.0
#     }
# ]
#   symbol        date period  revenueGrowth  grossProfitGrowth  ebitgrowth  \
# 0   AAPL  2022-03-26     Q2      -0.215152          -0.215401   -0.277406
#
#    operatingIncomeGrowth  netIncomeGrowth  epsgrowth  epsdilutedGrowth  ...  \
# 0              -0.277406        -0.277794  -0.274882         -0.280952  ...
#
#    tenYDividendperShareGrowthPerShare  fiveYDividendperShareGrowthPerShare  \
# 0                                 0.0                             0.526112
#
#    threeYDividendperShareGrowthPerShare  receivablesGrowth  inventoryGrowth  \
# 0                              0.190947          -0.304247        -0.070796
#
#    assetGrowth  bookValueperShareGrowth  debtGrowth  rdexpenseGrowth  \
# 0    -0.080088                -0.063018    -0.02294         0.012845
#
#    sgaexpensesGrowth
# 0                0.0
#
# [1 rows x 37 columns]

# %%
def get_jsonparsed_data(url):
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

# %%
url = ("https://financialmodelingprep.com/api/v4/treasury?from=2021-06-30&to=2021-09-30&apikey=eef11245e039afd02560c03e5e86851d")

# %%
data=get_jsonparsed_data(url)
print(json.dumps(data, indent=4))
pd.DataFrame(data)
# Out:
# C:\Users\mct46\AppData\Local\Temp\ipykernel_13416\654040892.py:2: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())
# [
#     {
#         "date": "2021-09-30",
#         "month1": 0.07,
#         "month2": 0.05,
#         "month3": 0.04,
#         "month6": 0.05,
#         "year1": 0.09,
#         "year2": 0.28,
#         "year3": 0.53,
#         "year5": 0.98,
#         "year7": 1.32,
#         "year10": 1.52,
#         "year20": 2.02,
#         "year30": 2.08
#     },
#     {
#         "date": "2021-09-29",
#         "month1": 0.05,
#         "month2": 0.04,
#         "month3": 0.04,
#         "month6": 0.05,
#         "year1": 0.09,
#         "year2": 0.3,
#         "year3": 0.55,
#         "year5": 1.01,
#         "year7": 1.34,
#         "year10": 1.55,
#         "year20": 2.04,
#         "year30": 2.09
#     },
#     {
#         "date": "2021-09-28",
#         "month1": 0.07,
#         "month2": 0.04,
#         "month3": 0.04,
#         "month6": 0.06,
#         "year1": 0.09,
#         "year2": 0.31,
#         "year3": 0.55,
#         "year5": 1.02,
#         "year7": 1.34,
#         "year10": 1.54,
#         "year20": 2.02,
#         "year30": 2.07
#     },
#     {
#         "date": "2021-09-27",
#         "month1": 0.06,
#         "month2": 0.03,
#         "month3": 0.04,
#         "month6": 0.05,
#         "year1": 0.09,
#         "year2": 0.31,
#         "year3": 0.56,
#         "year5": 0.98,
#         "year7": 1.3,
#         "year10": 1.48,
#         "year20": 1.95,
#         "year30": 1.99
#     },
#     {
#         "date": "2021-09-24",
#         "month1": 0.06,
#         "month2": 0.04,
#         "month3": 0.03,
#         "month6": 0.05,
#         "year1": 0.08,
#         "year2": 0.29,
#         "year3": 0.55,
#         "year5": 0.97,
#         "year7": 1.27,
#         "year10": 1.47,
#         "year20": 1.94,
#         "year30": 1.99
#     },
#     {
#         "date": "2021-09-23",
#         "month1": 0.05,
#         "month2": 0.04,
#         "month3": 0.03,
#         "month6": 0.04,
#         "year1": 0.08,
#         "year2": 0.27,
#         "year3": 0.53,
#         "year5": 0.94,
#         "year7": 1.22,
#         "year10": 1.41,
#         "year20": 1.87,
#         "year30": 1.92
#     },
#     {
#         "date": "2021-09-22",
#         "month1": 0.04,
#         "month2": 0.04,
#         "month3": 0.03,
#         "month6": 0.05,
#         "year1": 0.08,
#         "year2": 0.25,
#         "year3": 0.48,
#         "year5": 0.86,
#         "year7": 1.13,
#         "year10": 1.32,
#         "year20": 1.78,
#         "year30": 1.84
#     },
#     {
#         "date": "2021-09-21",
#         "month1": 0.05,
#         "month2": 0.04,
#         "month3": 0.03,
#         "month6": 0.04,
#         "year1": 0.07,
#         "year2": 0.22,
#         "year3": 0.46,
#         "year5": 0.84,
#         "year7": 1.13,
#         "year10": 1.33,
#         "year20": 1.81,
#         "year30": 1.86
#     },
#     {
#         "date": "2021-09-20",
#         "month1": 0.06,
#         "month2": 0.05,
#         "month3": 0.04,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.23,
#         "year3": 0.45,
#         "year5": 0.83,
#         "year7": 1.12,
#         "year10": 1.31,
#         "year20": 1.79,
#         "year30": 1.85
#     },
#     {
#         "date": "2021-09-17",
#         "month1": 0.06,
#         "month2": 0.06,
#         "month3": 0.04,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.23,
#         "year3": 0.47,
#         "year5": 0.88,
#         "year7": 1.17,
#         "year10": 1.37,
#         "year20": 1.85,
#         "year30": 1.91
#     },
#     {
#         "date": "2021-09-16",
#         "month1": 0.06,
#         "month2": 0.06,
#         "month3": 0.04,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.23,
#         "year3": 0.46,
#         "year5": 0.84,
#         "year7": 1.13,
#         "year10": 1.34,
#         "year20": 1.83,
#         "year30": 1.88
#     },
#     {
#         "date": "2021-09-15",
#         "month1": 0.04,
#         "month2": 0.06,
#         "month3": 0.04,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.21,
#         "year3": 0.43,
#         "year5": 0.81,
#         "year7": 1.1,
#         "year10": 1.31,
#         "year20": 1.8,
#         "year30": 1.87
#     },
#     {
#         "date": "2021-09-14",
#         "month1": 0.05,
#         "month2": 0.06,
#         "month3": 0.04,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.21,
#         "year3": 0.43,
#         "year5": 0.79,
#         "year7": 1.07,
#         "year10": 1.28,
#         "year20": 1.78,
#         "year30": 1.85
#     },
#     {
#         "date": "2021-09-13",
#         "month1": 0.06,
#         "month2": 0.08,
#         "month3": 0.06,
#         "month6": 0.06,
#         "year1": 0.07,
#         "year2": 0.21,
#         "year3": 0.44,
#         "year5": 0.81,
#         "year7": 1.11,
#         "year10": 1.33,
#         "year20": 1.83,
#         "year30": 1.91
#     },
#     {
#         "date": "2021-09-10",
#         "month1": 0.06,
#         "month2": 0.06,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.08,
#         "year2": 0.23,
#         "year3": 0.45,
#         "year5": 0.82,
#         "year7": 1.12,
#         "year10": 1.35,
#         "year20": 1.86,
#         "year30": 1.94
#     },
#     {
#         "date": "2021-09-09",
#         "month1": 0.07,
#         "month2": 0.06,
#         "month3": 0.04,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.23,
#         "year3": 0.43,
#         "year5": 0.79,
#         "year7": 1.08,
#         "year10": 1.3,
#         "year20": 1.83,
#         "year30": 1.9
#     },
#     {
#         "date": "2021-09-08",
#         "month1": 0.05,
#         "month2": 0.06,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.08,
#         "year2": 0.22,
#         "year3": 0.43,
#         "year5": 0.81,
#         "year7": 1.11,
#         "year10": 1.35,
#         "year20": 1.88,
#         "year30": 1.95
#     },
#     {
#         "date": "2021-09-07",
#         "month1": 0.04,
#         "month2": 0.07,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.08,
#         "year2": 0.22,
#         "year3": 0.45,
#         "year5": 0.82,
#         "year7": 1.14,
#         "year10": 1.38,
#         "year20": 1.91,
#         "year30": 1.99
#     },
#     {
#         "date": "2021-09-03",
#         "month1": 0.04,
#         "month2": 0.07,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.08,
#         "year2": 0.21,
#         "year3": 0.42,
#         "year5": 0.78,
#         "year7": 1.09,
#         "year10": 1.33,
#         "year20": 1.87,
#         "year30": 1.94
#     },
#     {
#         "date": "2021-09-02",
#         "month1": 0.05,
#         "month2": 0.07,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.07,
#         "year2": 0.2,
#         "year3": 0.42,
#         "year5": 0.78,
#         "year7": 1.07,
#         "year10": 1.29,
#         "year20": 1.83,
#         "year30": 1.9
#     },
#     {
#         "date": "2021-09-01",
#         "month1": 0.04,
#         "month2": 0.06,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.07,
#         "year2": 0.2,
#         "year3": 0.42,
#         "year5": 0.78,
#         "year7": 1.08,
#         "year10": 1.31,
#         "year20": 1.84,
#         "year30": 1.92
#     },
#     {
#         "date": "2021-08-31",
#         "month1": 0.03,
#         "month2": 0.05,
#         "month3": 0.04,
#         "month6": 0.06,
#         "year1": 0.07,
#         "year2": 0.2,
#         "year3": 0.4,
#         "year5": 0.77,
#         "year7": 1.08,
#         "year10": 1.3,
#         "year20": 1.85,
#         "year30": 1.92
#     },
#     {
#         "date": "2021-08-30",
#         "month1": 0.04,
#         "month2": 0.07,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.08,
#         "year2": 0.2,
#         "year3": 0.4,
#         "year5": 0.77,
#         "year7": 1.07,
#         "year10": 1.29,
#         "year20": 1.82,
#         "year30": 1.9
#     },
#     {
#         "date": "2021-08-27",
#         "month1": 0.04,
#         "month2": 0.06,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.22,
#         "year3": 0.41,
#         "year5": 0.79,
#         "year7": 1.09,
#         "year10": 1.31,
#         "year20": 1.84,
#         "year30": 1.91
#     },
#     {
#         "date": "2021-08-26",
#         "month1": 0.04,
#         "month2": 0.06,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.07,
#         "year2": 0.25,
#         "year3": 0.46,
#         "year5": 0.84,
#         "year7": 1.13,
#         "year10": 1.34,
#         "year20": 1.87,
#         "year30": 1.94
#     },
#     {
#         "date": "2021-08-25",
#         "month1": 0.04,
#         "month2": 0.05,
#         "month3": 0.06,
#         "month6": 0.06,
#         "year1": 0.07,
#         "year2": 0.23,
#         "year3": 0.47,
#         "year5": 0.84,
#         "year7": 1.13,
#         "year10": 1.35,
#         "year20": 1.88,
#         "year30": 1.96
#     },
#     {
#         "date": "2021-08-24",
#         "month1": 0.03,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.06,
#         "year2": 0.24,
#         "year3": 0.44,
#         "year5": 0.8,
#         "year7": 1.08,
#         "year10": 1.29,
#         "year20": 1.83,
#         "year30": 1.91
#     },
#     {
#         "date": "2021-08-23",
#         "month1": 0.04,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.07,
#         "year2": 0.23,
#         "year3": 0.43,
#         "year5": 0.78,
#         "year7": 1.05,
#         "year10": 1.25,
#         "year20": 1.79,
#         "year30": 1.87
#     },
#     {
#         "date": "2021-08-20",
#         "month1": 0.04,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.06,
#         "year2": 0.23,
#         "year3": 0.44,
#         "year5": 0.8,
#         "year7": 1.06,
#         "year10": 1.26,
#         "year20": 1.79,
#         "year30": 1.87
#     },
#     {
#         "date": "2021-08-19",
#         "month1": 0.04,
#         "month2": 0.05,
#         "month3": 0.06,
#         "month6": 0.05,
#         "year1": 0.06,
#         "year2": 0.22,
#         "year3": 0.44,
#         "year5": 0.78,
#         "year7": 1.04,
#         "year10": 1.24,
#         "year20": 1.8,
#         "year30": 1.88
#     },
#     {
#         "date": "2021-08-18",
#         "month1": 0.03,
#         "month2": 0.05,
#         "month3": 0.07,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.23,
#         "year3": 0.43,
#         "year5": 0.79,
#         "year7": 1.06,
#         "year10": 1.27,
#         "year20": 1.84,
#         "year30": 1.91
#     },
#     {
#         "date": "2021-08-17",
#         "month1": 0.03,
#         "month2": 0.05,
#         "month3": 0.07,
#         "month6": 0.06,
#         "year1": 0.07,
#         "year2": 0.23,
#         "year3": 0.43,
#         "year5": 0.77,
#         "year7": 1.05,
#         "year10": 1.26,
#         "year20": 1.82,
#         "year30": 1.92
#     },
#     {
#         "date": "2021-08-16",
#         "month1": 0.04,
#         "month2": 0.05,
#         "month3": 0.06,
#         "month6": 0.05,
#         "year1": 0.08,
#         "year2": 0.21,
#         "year3": 0.42,
#         "year5": 0.75,
#         "year7": 1.04,
#         "year10": 1.26,
#         "year20": 1.82,
#         "year30": 1.92
#     },
#     {
#         "date": "2021-08-13",
#         "month1": 0.04,
#         "month2": 0.05,
#         "month3": 0.06,
#         "month6": 0.05,
#         "year1": 0.08,
#         "year2": 0.23,
#         "year3": 0.44,
#         "year5": 0.79,
#         "year7": 1.08,
#         "year10": 1.29,
#         "year20": 1.85,
#         "year30": 1.94
#     },
#     {
#         "date": "2021-08-12",
#         "month1": 0.05,
#         "month2": 0.06,
#         "month3": 0.06,
#         "month6": 0.06,
#         "year1": 0.09,
#         "year2": 0.23,
#         "year3": 0.46,
#         "year5": 0.83,
#         "year7": 1.13,
#         "year10": 1.36,
#         "year20": 1.92,
#         "year30": 2.03
#     },
#     {
#         "date": "2021-08-11",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.08,
#         "year2": 0.23,
#         "year3": 0.45,
#         "year5": 0.81,
#         "year7": 1.11,
#         "year10": 1.35,
#         "year20": 1.9,
#         "year30": 1.99
#     },
#     {
#         "date": "2021-08-10",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.08,
#         "year2": 0.24,
#         "year3": 0.47,
#         "year5": 0.82,
#         "year7": 1.12,
#         "year10": 1.36,
#         "year20": 1.9,
#         "year30": 1.99
#     },
#     {
#         "date": "2021-08-09",
#         "month1": 0.04,
#         "month2": 0.05,
#         "month3": 0.06,
#         "month6": 0.06,
#         "year1": 0.08,
#         "year2": 0.23,
#         "year3": 0.43,
#         "year5": 0.79,
#         "year7": 1.09,
#         "year10": 1.33,
#         "year20": 1.87,
#         "year30": 1.96
#     },
#     {
#         "date": "2021-08-06",
#         "month1": 0.04,
#         "month2": 0.05,
#         "month3": 0.06,
#         "month6": 0.06,
#         "year1": 0.09,
#         "year2": 0.21,
#         "year3": 0.42,
#         "year5": 0.77,
#         "year7": 1.07,
#         "year10": 1.31,
#         "year20": 1.85,
#         "year30": 1.94
#     },
#     {
#         "date": "2021-08-05",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.08,
#         "year2": 0.21,
#         "year3": 0.38,
#         "year5": 0.72,
#         "year7": 1.01,
#         "year10": 1.23,
#         "year20": 1.77,
#         "year30": 1.86
#     },
#     {
#         "date": "2021-08-04",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.17,
#         "year3": 0.34,
#         "year5": 0.67,
#         "year7": 0.96,
#         "year10": 1.19,
#         "year20": 1.74,
#         "year30": 1.83
#     },
#     {
#         "date": "2021-08-03",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.07,
#         "year2": 0.17,
#         "year3": 0.33,
#         "year5": 0.65,
#         "year7": 0.95,
#         "year10": 1.19,
#         "year20": 1.76,
#         "year30": 1.85
#     },
#     {
#         "date": "2021-08-02",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.07,
#         "year2": 0.17,
#         "year3": 0.33,
#         "year5": 0.66,
#         "year7": 0.96,
#         "year10": 1.2,
#         "year20": 1.77,
#         "year30": 1.86
#     },
#     {
#         "date": "2021-07-30",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.06,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.19,
#         "year3": 0.35,
#         "year5": 0.69,
#         "year7": 1.0,
#         "year10": 1.24,
#         "year20": 1.81,
#         "year30": 1.89
#     },
#     {
#         "date": "2021-07-29",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.06,
#         "month6": 0.05,
#         "year1": 0.08,
#         "year2": 0.2,
#         "year3": 0.37,
#         "year5": 0.73,
#         "year7": 1.04,
#         "year10": 1.28,
#         "year20": 1.84,
#         "year30": 1.91
#     },
#     {
#         "date": "2021-07-28",
#         "month1": 0.04,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.2,
#         "year3": 0.38,
#         "year5": 0.72,
#         "year7": 1.01,
#         "year10": 1.26,
#         "year20": 1.83,
#         "year30": 1.9
#     },
#     {
#         "date": "2021-07-27",
#         "month1": 0.04,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.2,
#         "year3": 0.37,
#         "year5": 0.71,
#         "year7": 1.01,
#         "year10": 1.25,
#         "year20": 1.81,
#         "year30": 1.89
#     },
#     {
#         "date": "2021-07-26",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.08,
#         "year2": 0.22,
#         "year3": 0.38,
#         "year5": 0.73,
#         "year7": 1.04,
#         "year10": 1.29,
#         "year20": 1.85,
#         "year30": 1.93
#     },
#     {
#         "date": "2021-07-23",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.22,
#         "year3": 0.38,
#         "year5": 0.72,
#         "year7": 1.04,
#         "year10": 1.3,
#         "year20": 1.85,
#         "year30": 1.92
#     },
#     {
#         "date": "2021-07-22",
#         "month1": 0.04,
#         "month2": 0.04,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.2,
#         "year3": 0.37,
#         "year5": 0.71,
#         "year7": 1.02,
#         "year10": 1.27,
#         "year20": 1.82,
#         "year30": 1.9
#     },
#     {
#         "date": "2021-07-21",
#         "month1": 0.04,
#         "month2": 0.04,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.22,
#         "year3": 0.39,
#         "year5": 0.74,
#         "year7": 1.05,
#         "year10": 1.3,
#         "year20": 1.87,
#         "year30": 1.94
#     },
#     {
#         "date": "2021-07-20",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.08,
#         "year2": 0.2,
#         "year3": 0.37,
#         "year5": 0.69,
#         "year7": 0.98,
#         "year10": 1.23,
#         "year20": 1.79,
#         "year30": 1.88
#     },
#     {
#         "date": "2021-07-19",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.07,
#         "year2": 0.21,
#         "year3": 0.38,
#         "year5": 0.7,
#         "year7": 0.97,
#         "year10": 1.19,
#         "year20": 1.74,
#         "year30": 1.81
#     },
#     {
#         "date": "2021-07-16",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.08,
#         "year2": 0.25,
#         "year3": 0.43,
#         "year5": 0.79,
#         "year7": 1.08,
#         "year10": 1.31,
#         "year20": 1.86,
#         "year30": 1.93
#     },
#     {
#         "date": "2021-07-15",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.07,
#         "year2": 0.23,
#         "year3": 0.43,
#         "year5": 0.78,
#         "year7": 1.07,
#         "year10": 1.31,
#         "year20": 1.85,
#         "year30": 1.92
#     },
#     {
#         "date": "2021-07-14",
#         "month1": 0.06,
#         "month2": 0.05,
#         "month3": 0.06,
#         "month6": 0.05,
#         "year1": 0.08,
#         "year2": 0.23,
#         "year3": 0.44,
#         "year5": 0.8,
#         "year7": 1.11,
#         "year10": 1.37,
#         "year20": 1.91,
#         "year30": 1.98
#     },
#     {
#         "date": "2021-07-13",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.08,
#         "year2": 0.26,
#         "year3": 0.47,
#         "year5": 0.85,
#         "year7": 1.16,
#         "year10": 1.42,
#         "year20": 1.96,
#         "year30": 2.04
#     },
#     {
#         "date": "2021-07-12",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.08,
#         "year2": 0.23,
#         "year3": 0.43,
#         "year5": 0.81,
#         "year7": 1.13,
#         "year10": 1.38,
#         "year20": 1.93,
#         "year30": 2.0
#     },
#     {
#         "date": "2021-07-09",
#         "month1": 0.06,
#         "month2": 0.05,
#         "month3": 0.06,
#         "month6": 0.05,
#         "year1": 0.08,
#         "year2": 0.23,
#         "year3": 0.41,
#         "year5": 0.79,
#         "year7": 1.12,
#         "year10": 1.37,
#         "year20": 1.91,
#         "year30": 1.99
#     },
#     {
#         "date": "2021-07-08",
#         "month1": 0.06,
#         "month2": 0.05,
#         "month3": 0.06,
#         "month6": 0.06,
#         "year1": 0.07,
#         "year2": 0.19,
#         "year3": 0.37,
#         "year5": 0.74,
#         "year7": 1.06,
#         "year10": 1.3,
#         "year20": 1.84,
#         "year30": 1.91
#     },
#     {
#         "date": "2021-07-07",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.08,
#         "year2": 0.22,
#         "year3": 0.41,
#         "year5": 0.79,
#         "year7": 1.09,
#         "year10": 1.33,
#         "year20": 1.87,
#         "year30": 1.94
#     },
#     {
#         "date": "2021-07-06",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.07,
#         "year2": 0.22,
#         "year3": 0.42,
#         "year5": 0.81,
#         "year7": 1.13,
#         "year10": 1.37,
#         "year20": 1.92,
#         "year30": 2.0
#     },
#     {
#         "date": "2021-07-02",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.08,
#         "year2": 0.24,
#         "year3": 0.45,
#         "year5": 0.86,
#         "year7": 1.19,
#         "year10": 1.44,
#         "year20": 1.98,
#         "year30": 2.05
#     },
#     {
#         "date": "2021-07-01",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.05,
#         "year1": 0.09,
#         "year2": 0.25,
#         "year3": 0.47,
#         "year5": 0.89,
#         "year7": 1.24,
#         "year10": 1.48,
#         "year20": 2.01,
#         "year30": 2.07
#     },
#     {
#         "date": "2021-06-30",
#         "month1": 0.05,
#         "month2": 0.05,
#         "month3": 0.05,
#         "month6": 0.06,
#         "year1": 0.07,
#         "year2": 0.25,
#         "year3": 0.46,
#         "year5": 0.87,
#         "year7": 1.21,
#         "year10": 1.45,
#         "year20": 2.0,
#         "year30": 2.06
#     }
# ]
#           date  month1  month2  month3  month6  year1  year2  year3  year5  \
# 0   2021-09-30    0.07    0.05    0.04    0.05   0.09   0.28   0.53   0.98
# 1   2021-09-29    0.05    0.04    0.04    0.05   0.09   0.30   0.55   1.01
# 2   2021-09-28    0.07    0.04    0.04    0.06   0.09   0.31   0.55   1.02
# 3   2021-09-27    0.06    0.03    0.04    0.05   0.09   0.31   0.56   0.98
# 4   2021-09-24    0.06    0.04    0.03    0.05   0.08   0.29   0.55   0.97
# ..         ...     ...     ...     ...     ...    ...    ...    ...    ...
# 60  2021-07-07    0.05    0.05    0.05    0.05   0.08   0.22   0.41   0.79
# 61  2021-07-06    0.05    0.05    0.05    0.06   0.07   0.22   0.42   0.81
# 62  2021-07-02    0.05    0.05    0.05    0.05   0.08   0.24   0.45   0.86
# 63  2021-07-01    0.05    0.05    0.05    0.05   0.09   0.25   0.47   0.89
# 64  2021-06-30    0.05    0.05    0.05    0.06   0.07   0.25   0.46   0.87
#
#     year7  year10  year20  year30
# 0    1.32    1.52    2.02    2.08
# 1    1.34    1.55    2.04    2.09
# 2    1.34    1.54    2.02    2.07
# 3    1.30    1.48    1.95    1.99
# 4    1.27    1.47    1.94    1.99
# ..    ...     ...     ...     ...
# 60   1.09    1.33    1.87    1.94
# 61   1.13    1.37    1.92    2.00
# 62   1.19    1.44    1.98    2.05
# 63   1.24    1.48    2.01    2.07
# 64   1.21    1.45    2.00    2.06
#
# [65 rows x 13 columns]

# %%
pd.DataFrame(data).T
# Out:
#                 0           1           2           3           4   \
# date    2021-09-30  2021-09-29  2021-09-28  2021-09-27  2021-09-24
# month1        0.07        0.05        0.07        0.06        0.06
# month2        0.05        0.04        0.04        0.03        0.04
# month3        0.04        0.04        0.04        0.04        0.03
# month6        0.05        0.05        0.06        0.05        0.05
# year1         0.09        0.09        0.09        0.09        0.08
# year2         0.28         0.3        0.31        0.31        0.29
# year3         0.53        0.55        0.55        0.56        0.55
# year5         0.98        1.01        1.02        0.98        0.97
# year7         1.32        1.34        1.34         1.3        1.27
# year10        1.52        1.55        1.54        1.48        1.47
# year20        2.02        2.04        2.02        1.95        1.94
# year30        2.08        2.09        2.07        1.99        1.99
#
#                 5           6           7           8           9   ...  \
# date    2021-09-23  2021-09-22  2021-09-21  2021-09-20  2021-09-17  ...
# month1        0.05        0.04        0.05        0.06        0.06  ...
# month2        0.04        0.04        0.04        0.05        0.06  ...
# month3        0.03        0.03        0.03        0.04        0.04  ...
# month6        0.04        0.05        0.04        0.05        0.05  ...
# year1         0.08        0.08        0.07        0.07        0.07  ...
# year2         0.27        0.25        0.22        0.23        0.23  ...
# year3         0.53        0.48        0.46        0.45        0.47  ...
# year5         0.94        0.86        0.84        0.83        0.88  ...
# year7         1.22        1.13        1.13        1.12        1.17  ...
# year10        1.41        1.32        1.33        1.31        1.37  ...
# year20        1.87        1.78        1.81        1.79        1.85  ...
# year30        1.92        1.84        1.86        1.85        1.91  ...
#
#                 55          56          57          58          59  \
# date    2021-07-14  2021-07-13  2021-07-12  2021-07-09  2021-07-08
# month1        0.06        0.05        0.05        0.06        0.06
# month2        0.05        0.05        0.05        0.05        0.05
# month3        0.06        0.05        0.05        0.06        0.06
# month6        0.05        0.06        0.06        0.05        0.06
# year1         0.08        0.08        0.08        0.08        0.07
# year2         0.23        0.26        0.23        0.23        0.19
# year3         0.44        0.47        0.43        0.41        0.37
# year5          0.8        0.85        0.81        0.79        0.74
# year7         1.11        1.16        1.13        1.12        1.06
# year10        1.37        1.42        1.38        1.37         1.3
# year20        1.91        1.96        1.93        1.91        1.84
# year30        1.98        2.04         2.0        1.99        1.91
#
#                 60          61          62          63          64
# date    2021-07-07  2021-07-06  2021-07-02  2021-07-01  2021-06-30
# month1        0.05        0.05        0.05        0.05        0.05
# month2        0.05        0.05        0.05        0.05        0.05
# month3        0.05        0.05        0.05        0.05        0.05
# month6        0.05        0.06        0.05        0.05        0.06
# year1         0.08        0.07        0.08        0.09        0.07
# year2         0.22        0.22        0.24        0.25        0.25
# year3         0.41        0.42        0.45        0.47        0.46
# year5         0.79        0.81        0.86        0.89        0.87
# year7         1.09        1.13        1.19        1.24        1.21
# year10        1.33        1.37        1.44        1.48        1.45
# year20        1.87        1.92        1.98        2.01         2.0
# year30        1.94         2.0        2.05        2.07        2.06
#
# [13 rows x 65 columns]

# %%
def get_jsonparsed_data(url):
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

# %%
url = ("https://financialmodelingprep.com/api/v4/economic?name=smoothedUSRecessionProbabilities&from=2019-07-10&to=2022-07-10&apikey=eef11245e039afd02560c03e5e86851d")

# %%
data=get_jsonparsed_data(url)
print(json.dumps(data, indent=4))
pd.DataFrame(data)
# Out:
# C:\Users\mct46\AppData\Local\Temp\ipykernel_13416\654040892.py:2: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())
# [
#     {
#         "date": "2022-05-01",
#         "value": 0.48
#     },
#     {
#         "date": "2022-04-01",
#         "value": 0.04
#     },
#     {
#         "date": "2022-03-01",
#         "value": 0.06
#     },
#     {
#         "date": "2022-02-01",
#         "value": 0.02
#     },
#     {
#         "date": "2022-01-01",
#         "value": 0.02
#     },
#     {
#         "date": "2021-12-01",
#         "value": 0.1
#     },
#     {
#         "date": "2021-11-01",
#         "value": 0.02
#     },
#     {
#         "date": "2021-10-01",
#         "value": 0.02
#     },
#     {
#         "date": "2021-09-01",
#         "value": 0.36
#     },
#     {
#         "date": "2021-08-01",
#         "value": 0.34
#     },
#     {
#         "date": "2021-07-01",
#         "value": 0.04
#     },
#     {
#         "date": "2021-06-01",
#         "value": 0.02
#     },
#     {
#         "date": "2021-05-01",
#         "value": 0.1
#     },
#     {
#         "date": "2021-04-01",
#         "value": 0.52
#     },
#     {
#         "date": "2021-03-01",
#         "value": 0.02
#     },
#     {
#         "date": "2021-02-01",
#         "value": 0.02
#     },
#     {
#         "date": "2021-01-01",
#         "value": 0.0
#     },
#     {
#         "date": "2020-12-01",
#         "value": 0.04
#     },
#     {
#         "date": "2020-11-01",
#         "value": 0.44
#     },
#     {
#         "date": "2020-10-01",
#         "value": 0.02
#     },
#     {
#         "date": "2020-09-01",
#         "value": 0.02
#     },
#     {
#         "date": "2020-08-01",
#         "value": 0.0
#     },
#     {
#         "date": "2020-07-01",
#         "value": 0.0
#     },
#     {
#         "date": "2020-06-01",
#         "value": 0.02
#     },
#     {
#         "date": "2020-05-01",
#         "value": 0.04
#     },
#     {
#         "date": "2020-04-01",
#         "value": 100.0
#     },
#     {
#         "date": "2020-03-01",
#         "value": 100.0
#     },
#     {
#         "date": "2020-02-01",
#         "value": 0.2
#     },
#     {
#         "date": "2020-01-01",
#         "value": 0.22
#     },
#     {
#         "date": "2019-12-01",
#         "value": 0.5
#     },
#     {
#         "date": "2019-11-01",
#         "value": 0.4
#     },
#     {
#         "date": "2019-10-01",
#         "value": 1.24
#     },
#     {
#         "date": "2019-09-01",
#         "value": 0.84
#     },
#     {
#         "date": "2019-08-01",
#         "value": 0.24
#     }
# ]
#           date   value
# 0   2022-05-01    0.48
# 1   2022-04-01    0.04
# 2   2022-03-01    0.06
# 3   2022-02-01    0.02
# 4   2022-01-01    0.02
# 5   2021-12-01    0.10
# 6   2021-11-01    0.02
# 7   2021-10-01    0.02
# 8   2021-09-01    0.36
# 9   2021-08-01    0.34
# 10  2021-07-01    0.04
# 11  2021-06-01    0.02
# 12  2021-05-01    0.10
# 13  2021-04-01    0.52
# 14  2021-03-01    0.02
# 15  2021-02-01    0.02
# 16  2021-01-01    0.00
# 17  2020-12-01    0.04
# 18  2020-11-01    0.44
# 19  2020-10-01    0.02
# 20  2020-09-01    0.02
# 21  2020-08-01    0.00
# 22  2020-07-01    0.00
# 23  2020-06-01    0.02
# 24  2020-05-01    0.04
# 25  2020-04-01  100.00
# 26  2020-03-01  100.00
# 27  2020-02-01    0.20
# 28  2020-01-01    0.22
# 29  2019-12-01    0.50
# 30  2019-11-01    0.40
# 31  2019-10-01    1.24
# 32  2019-09-01    0.84
# 33  2019-08-01    0.24

# %%
url = ("https://financialmodelingprep.com/api/v4/economic?name=GDP&from=2019-10-10&to=2021-11-10&apikey=eef11245e039afd02560c03e5e86851d")
