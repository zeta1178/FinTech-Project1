# %%
try:
    # For Python 3.0 and later
    from urllib.request import urlopen
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen
    
import pandas as pd
import certifi
import json
from pathlib import Path
# %matplotlib inline

# %%
def get_jsonparsed_data(url):
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

# %%
url = ("https://financialmodelingprep.com/api/v3/earning_calendar?from=2022-07-28&to=2022-08-11&apikey=eef11245e039afd02560c03e5e86851d")
#print(get_jsonparsed_data(url))
test = urlopen(url)
test = json.loads(test.read())
test = pd.DataFrame(test)
test
# Out:
#             date symbol   eps  epsEstimated time  revenue  revenueEstimated  \
# 0     2022-07-28    TXT  None          0.88  bmo        0      3.167420e+09
# 1     2022-07-28    CPT  None          1.62  amc        0      3.435400e+08
# 2     2022-07-28    LKQ  None          1.02  bmo        0      3.447920e+09
# 3     2022-07-28    BIO  None          2.46  amc        0      6.826200e+08
# 4     2022-07-28     IP  None          1.10  bmo        0      5.357200e+09
# ...          ...    ...   ...           ...  ...      ...               ...
# 4034  2022-08-11   SNDA  None           NaN  bmo        0      6.150000e+07
# 4035  2022-08-11   BDTX  None         -0.73  bmo        0               NaN
# 4036  2022-08-11   MNOV  None         -0.08  amc        0               NaN
# 4037  2022-08-11   PDSB  None         -0.30  bmo        0               NaN
# 4038  2022-08-11   LHDX  None         -0.30  amc        0      3.005000e+07
#
#      updatedFromDate fiscalDateEnding
# ...

# %%
pd.DataFrame(test).T
# Out:
#                           0            1             2            3     \
# date                2022-07-28   2022-07-28    2022-07-28   2022-07-28
# symbol                     TXT          CPT           LKQ          BIO
# eps                       None         None          None         None
# epsEstimated              0.88         1.62          1.02         2.46
# time                       bmo          amc           bmo          amc
# revenue                      0            0             0            0
# revenueEstimated  3167420000.0  343540000.0  3447920000.0  682620000.0
# updatedFromDate     2022-07-27   2022-07-27    2022-08-04   2022-07-27
# fiscalDateEnding    2022-06-30   2022-06-30    2022-06-30   2022-06-30
#
#                           4           5            6           7     \
# date                2022-07-28  2022-07-28   2022-07-28  2022-07-28
# symbol                      IP      4956.T          LAZ       MLRYY
# ...

# %%
pd.DataFrame(data).T
# Out:
#                 0           1           2           3           4   \
# date    2021-09-30  2021-09-29  2021-09-28  2021-09-27  2021-09-24
# month1        0.07        0.05        0.07        0.06        0.06
# month2        0.05        0.04        0.04        0.03        0.04
# month3        0.04        0.04        0.04        0.04        0.03
# month6        0.05        0.05        0.06        0.05        0.05
# year1         0.09        0.09        0.09        0.09        0.08
# year2         0.28         0.3        0.31        0.31        0.29
# year3         0.53        0.55        0.55        0.56        0.55
# year5         0.98        1.01        1.02        0.98        0.97
# year7         1.32        1.34        1.34         1.3        1.27
# year10        1.52        1.55        1.54        1.48        1.47
# year20        2.02        2.04        2.02        1.95        1.94
# year30        2.08        2.09        2.07        1.99        1.99
#
# ...

# %%
print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "date": "2021-09-30",
#         "month1": 0.07,
#         "month2": 0.05,
#         "month3": 0.04,
#         "month6": 0.05,
#         "year1": 0.09,
#         "year2": 0.28,
#         "year3": 0.53,
#         "year5": 0.98,
#         "year7": 1.32,
#         "year10": 1.52,
#         "year20": 2.02,
#         "year30": 2.08
#     },
#     {
#         "date": "2021-09-29",
#         "month1": 0.05,
#         "month2": 0.04,
#         "month3": 0.04,
#         "month6": 0.05,
#         "year1": 0.09,
#         "year2": 0.3,
#         "year3": 0.55,
#         "year5": 1.01,
#         "year7": 1.34,
#         "year10": 1.55,
#         "year20": 2.04,
#         "year30": 2.09
#     },
#     {
#         "date": "2021-09-28",
#         "month1": 0.07,
#         "month2": 0.04,
#         "month3": 0.04,
#         "month6": 0.06,
#         "year1": 0.09,
#         "year2": 0.31,
#         "year3": 0.55,
#         "year5": 1.02,
#         "year7": 1.34,
# ...

# %%
def get_jsonparsed_data(url):
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

url = ("https://financialmodelingprep.com/api/v3/key-metrics/AAPL?period=quarter&limit=5&apikey=eef11245e039afd02560c03e5e86851d")
data=get_jsonparsed_data(url)
# Out:
# C:\Users\mct46\AppData\Local\Temp\ipykernel_420\724873780.py:2: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())

# %%
print(json.dumps(data, indent=4))
pd.DataFrame(data)
# Out:
# [
#     {
#         "symbol": "AAPL",
#         "date": "2022-03-26",
#         "period": "Q2",
#         "revenuePerShare": 5.9345801576454065,
#         "netIncomePerShare": 1.5257699556190674,
#         "operatingCashFlowPerShare": 1.718306140342529,
#         "freeCashFlowPerShare": 1.5649360616369579,
#         "cashPerShare": 3.14250044717688,
#         "bookValuePerShare": 4.11177006152617,
#         "tangibleBookValuePerShare": 4.11177006152617,
#         "shareholdersEquityPerShare": 4.11177006152617,
#         "interestDebtPerShare": 7.3617637778674165,
#         "marketCap": 2863962036950.069,
#         "enterpriseValue": 2955845036950.069,
#         "peRatio": 28.628169101859946,
#         "priceToSalesRatio": 29.441004512326213,
#         "pocfratio": 101.68153223567666,
#         "pfcfRatio": 111.64673463862735,
#         "pbRatio": 42.49264880710499,
#         "ptbRatio": 42.49264880710499,
#         "evToSales": 30.385544901725662,
# ...

# %%
url = ("https://financialmodelingprep.com/api/v3/financial-growth/AAPL?period=quarter&limit=1&apikey=eef11245e039afd02560c03e5e86851d")

# %%
data=get_jsonparsed_data(url)
print(json.dumps(data, indent=4))
pd.DataFrame(data)
# Out:
# [
#     {
#         "symbol": "AAPL",
#         "date": "2022-03-26",
#         "period": "Q2",
#         "revenueGrowth": -0.2151518818830933,
#         "grossProfitGrowth": -0.2154010655752816,
#         "ebitgrowth": -0.2774055148476668,
#         "operatingIncomeGrowth": -0.2774055148476668,
#         "netIncomeGrowth": -0.2777938203869477,
#         "epsgrowth": -0.2748815165876777,
#         "epsdilutedGrowth": -0.28095238095238095,
#         "weightedAverageSharesGrowth": 0.0,
#         "weightedAverageSharesDilutedGrowth": 0.0,
#         "dividendsperShareGrowth": -0.036709539121114645,
#         "operatingCashFlowGrowth": -0.40028957117915087,
#         "freeCashFlowGrowth": -0.41915177863822656,
#         "tenYRevenueGrowthPerShare": 2.9588547429331293,
#         "fiveYRevenueGrowthPerShare": 1.3451962777224704,
#         "threeYRevenueGrowthPerShare": 0.9125156605723226,
#         "tenYOperatingCFGrowthPerShare": 2.2136389158740255,
# ...

# %%
def get_jsonparsed_data(url):
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

# %%
url = ("https://financialmodelingprep.com/api/v4/treasury?from=2021-06-30&to=2021-09-30&apikey=eef11245e039afd02560c03e5e86851d")

# %%
data=get_jsonparsed_data(url)
print(json.dumps(data, indent=4))
#pd.DataFrame(data)
# Out:
# [
#     {
#         "date": "2021-09-30",
#         "month1": 0.07,
#         "month2": 0.05,
#         "month3": 0.04,
#         "month6": 0.05,
#         "year1": 0.09,
#         "year2": 0.28,
#         "year3": 0.53,
#         "year5": 0.98,
#         "year7": 1.32,
#         "year10": 1.52,
#         "year20": 2.02,
#         "year30": 2.08
#     },
#     {
#         "date": "2021-09-29",
#         "month1": 0.05,
#         "month2": 0.04,
#         "month3": 0.04,
#         "month6": 0.05,
#         "year1": 0.09,
#         "year2": 0.3,
#         "year3": 0.55,
#         "year5": 1.01,
#         "year7": 1.34,
#         "year10": 1.55,
#         "year20": 2.04,
#         "year30": 2.09
#     },
#     {
#         "date": "2021-09-28",
#         "month1": 0.07,
#         "month2": 0.04,
#         "month3": 0.04,
#         "month6": 0.06,
#         "year1": 0.09,
#         "year2": 0.31,
#         "year3": 0.55,
#         "year5": 1.02,
#         "year7": 1.34,
# ...

# %%
pd.DataFrame(data)
#df.hvplot.line(data)
#dfhvplot.line(width=1000, , xlabel='Year' , ylabel='Gross Rent / Sale Price Per Square Foot', title='Federal Reserve Monthly Probability of Recession')
# Out:
#           date  month1  month2  month3  month6  year1  year2  year3  year5  \
# 0   2021-09-30    0.07    0.05    0.04    0.05   0.09   0.28   0.53   0.98
# 1   2021-09-29    0.05    0.04    0.04    0.05   0.09   0.30   0.55   1.01
# 2   2021-09-28    0.07    0.04    0.04    0.06   0.09   0.31   0.55   1.02
# 3   2021-09-27    0.06    0.03    0.04    0.05   0.09   0.31   0.56   0.98
# 4   2021-09-24    0.06    0.04    0.03    0.05   0.08   0.29   0.55   0.97
# ..         ...     ...     ...     ...     ...    ...    ...    ...    ...
# 60  2021-07-07    0.05    0.05    0.05    0.05   0.08   0.22   0.41   0.79
# 61  2021-07-06    0.05    0.05    0.05    0.06   0.07   0.22   0.42   0.81
# 62  2021-07-02    0.05    0.05    0.05    0.05   0.08   0.24   0.45   0.86
# 63  2021-07-01    0.05    0.05    0.05    0.05   0.09   0.25   0.47   0.89
# 64  2021-06-30    0.05    0.05    0.05    0.06   0.07   0.25   0.46   0.87
#
#     year7  year10  year20  year30
# ...

# %%
pd.DataFrame(data).T
# Out:
#                 0           1           2           3           4   \
# date    2021-09-30  2021-09-29  2021-09-28  2021-09-27  2021-09-24
# month1        0.07        0.05        0.07        0.06        0.06
# month2        0.05        0.04        0.04        0.03        0.04
# month3        0.04        0.04        0.04        0.04        0.03
# month6        0.05        0.05        0.06        0.05        0.05
# year1         0.09        0.09        0.09        0.09        0.08
# year2         0.28         0.3        0.31        0.31        0.29
# year3         0.53        0.55        0.55        0.56        0.55
# year5         0.98        1.01        1.02        0.98        0.97
# year7         1.32        1.34        1.34         1.3        1.27
# year10        1.52        1.55        1.54        1.48        1.47
# year20        2.02        2.04        2.02        1.95        1.94
# year30        2.08        2.09        2.07        1.99        1.99
#
# ...

# %%
def get_jsonparsed_data(url):
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

# %%
url = ("https://financialmodelingprep.com/api/v4/economic?name=smoothedUSRecessionProbabilities&from=2019-07-10&to=2022-07-10&apikey=eef11245e039afd02560c03e5e86851d")

# %%
data=get_jsonparsed_data(url)
print(json.dumps(data, indent=4))
# Out:
# [
#     {
#         "date": "2022-05-01",
#         "value": 0.48
#     },
#     {
#         "date": "2022-04-01",
#         "value": 0.04
#     },
#     {
#         "date": "2022-03-01",
#         "value": 0.06
#     },
#     {
#         "date": "2022-02-01",
#         "value": 0.02
#     },
#     {
#         "date": "2022-01-01",
#         "value": 0.02
#     },
#     {
#         "date": "2021-12-01",
#         "value": 0.1
#     },
#     {
#         "date": "2021-11-01",
#         "value": 0.02
#     },
#     {
#         "date": "2021-10-01",
#         "value": 0.02
#     },
#     {
#         "date": "2021-09-01",
#         "value": 0.36
#     },
#     {
#         "date": "2021-08-01",
#         "value": 0.34
#     },
#     {
#         "date": "2021-07-01",
#         "value": 0.04
#     },
#     {
#         "date": "2021-06-01",
#         "value": 0.02
#     },
#     {
#         "date": "2021-05-01",
#         "value": 0.1
#     },
#     {
#         "date": "2021-04-01",
# ...

# %%
var = pd.DataFrame(data)
var
# Out:
#           date   value
# 0   2022-05-01    0.48
# 1   2022-04-01    0.04
# 2   2022-03-01    0.06
# 3   2022-02-01    0.02
# 4   2022-01-01    0.02
# 5   2021-12-01    0.10
# 6   2021-11-01    0.02
# 7   2021-10-01    0.02
# 8   2021-09-01    0.36
# 9   2021-08-01    0.34
# 10  2021-07-01    0.04
# 11  2021-06-01    0.02
# 12  2021-05-01    0.10
# 13  2021-04-01    0.52
# 14  2021-03-01    0.02
# 15  2021-02-01    0.02
# 16  2021-01-01    0.00
# 17  2020-12-01    0.04
# 18  2020-11-01    0.44
# 19  2020-10-01    0.02
# 20  2020-09-01    0.02
# 21  2020-08-01    0.00
# 22  2020-07-01    0.00
# 23  2020-06-01    0.02
# 24  2020-05-01    0.04
# 25  2020-04-01  100.00
# 26  2020-03-01  100.00
# 27  2020-02-01    0.20
# 28  2020-01-01    0.22
# 29  2019-12-01    0.50
# 30  2019-11-01    0.40
# 31  2019-10-01    1.24
# 32  2019-09-01    0.84
# 33  2019-08-01    0.24

# %%
bar = var.set_index('date')
#data.head()
#plot(data)
#bar.plot(kind='bar',figsize=(20,20))
bar.plot.line(xlabel='Data', ylabel='% Chance', title='Fed Monthly Estimate for Recession from August 2019 to May 2022')
# Out:
# <AxesSubplot:title={'center':'Fed Monthly Estimate for Recession from August 2019 to May 2022'}, xlabel='Data', ylabel='% Chance'>

# %%
bar.plot.line(xlabel='Data', ylabel='% Chance', title='Fed Monthly Estimate for Recession from August 2019 to May 2022')
# Out:
# <AxesSubplot:title={'center':'Fed Monthly Estimate for Recession from August 2019 to May 2022'}, xlabel='Data', ylabel='% Chance'>

# %%
url = ("https://financialmodelingprep.com/api/v4/economic?name=GDP&from=2019-10-10&to=2021-11-10&apikey=eef11245e039afd02560c03e5e86851d")
